# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sqlalchemy import create_engine, inspect

# %%
engine = create_engine(f'postgresql://postgres:popo0909@localhost:5432/Company_tableschemata')
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['employees', 'departments', 'dept_manager', 'dept_emp', 'titles', 'salaries']

# %%
salaries = pd.read_sql("SELECT * FROM salaries", conn)
salaries
# Out:
#         emp_no  salary
# 0        10001   60117
# 1        10002   65828
# 2        10003   40006
# 3        10004   40054
# 4        10005   78228
# ...        ...     ...
# 300019  499995   40000
# 300020  499996   58058
# 300021  499997   49597
# 300022  499998   40000
# 300023  499999   63707
#
# [300024 rows x 2 columns]

# %%
employees = pd.read_sql("SELECT * FROM employees", conn)
employees
# Out:
#         emp_no emp_title_id  birth_date   first_name  last_name sex  \
# 0       473302        s0001  1953-07-25     Hideyuki   Zallocco   M
# 1       475053        e0002  1954-11-18        Byong  Delgrande   F
# 2        57444        e0002  1958-01-30        Berry       Babb   F
# 3       421786        s0001  1957-09-28        Xiong   Verhoeff   M
# 4       282238        e0003  1952-10-28   Abdelkader    Baumann   F
# ...        ...          ...         ...          ...        ...  ..
# 300019  464231        s0001  1958-08-14  Constantino    Eastman   M
# 300020  255832        e0002  1955-05-08       Yuping     Dayang   F
# 300021   76671        s0001  1959-06-09       Ortrud   Plessier   M
# 300022  264920        s0001  1959-09-22        Percy   Samarati   F
# 300023  464503        s0002  1964-05-31       Arvind  Slobodova   M
#
#          hire_date
# 0       1990-04-28
# 1       1991-09-07
# 2       1992-03-21
# 3       1987-11-26
# 4       1991-01-18
# ...            ...
# 300019  1988-10-28
# 300020  1995-02-26
# 300021  1988-02-24
# 300022  1994-09-08
# 300023  1987-11-23
#
# [300024 rows x 7 columns]

# %%
plt.figure(figsize=(15,8))
plt.hist(salaries["salary"], color='r');

plt.xlabel("Employees Count")
plt.ylabel('Salary')
plt.ylim(0,100000)
plt.title("Common Salary Range Per Employee")
plt.grid()

plt.show()
